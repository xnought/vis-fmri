# %%
import numpy as np
import nibabel as nib

# %%
PATH = "./ds000144_R1.0.0/sub-01/anat/sub-01_T1w.nii.gz"

# %%
img = nib.load(PATH)
img_data = np.asanyarray(img.dataobj)
img_data.shape
# Out:
# (256, 256, 166)

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")
plt.imshow(np.rot90(img_data[:, :, img_data.shape[2]//2]))

# %%
plt.imshow(np.rot90(img_data[:, img_data.shape[1]//2]))

# %%
plt.imshow(np.rot90(img_data[img_data.shape[0]//2, :, :]))
